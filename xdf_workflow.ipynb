# %% [raw]
# ---
# title: 'Processing I: from XDF to raw files'
# ---

# %% [markdown]
# As described in the preregistration of methods (@REF), the data has been collected using LabStreamLayer, allowing for recording of precisely synchronized streams. These streams include:
# - MicStream (16kHz)
# - WebcamFrameStream (ca. 60 Hz)
# - MarkerStream (sent from custom buttonbox)
# - BalanceBoardStream (500 Hz)
#
# LSL outputs single .xdf file that contains all the data streams. This script serves for extracting the streams and creating raw files for further processing.
#
# This script therefore creates each stream as a csv file (one for whole session, and one for ech trial), and  additionaly creates audio and video files for each trial.
#
# Additionally, in this script, we:
# - correct faulty delimitations of trials
# - align 16kHz audio and additional 48kHz audio that has been recorded outside of LSL, and cut this aligned audio to trial sized files
# - combine video and audio

# %%
#| code-fold: true
#| code-summary: Code to prepare the environment

# import packages
import os
import pyxdf
import glob
import pandas as pd
import numpy as np
import wave, struct, random
from scipy.io import wavfile
import noisereduce as nr
import cv2
import ffmpeg

# Set folders
curfolder = os.getcwd()
# If folder data doesn't exist, create it
if not os.path.exists(curfolder+'\\data\\'):
    os.makedirs(curfolder+'\\data\\')
datafolder = curfolder+'\\data\\'

# Also error_logs
if not os.path.exists(datafolder+'\\error_logs\\'):
    os.makedirs(datafolder+'\\error_logs\\')
errorlogs = datafolder+'\\error_logs\\'

experiment_to_process = curfolder + '\\raw\\'

# Also CsvDataTS_raw
if not os.path.exists(datafolder+'\\Data_processed\\CsvDataTS_raw\\'):
    os.makedirs(datafolder+'\\Data_processed\\CsvDataTS_raw\\')
outputfolder = datafolder+'\\Data_processed\\CsvDataTS_raw\\' # outputfolder raw

# Also Data_trials
if not os.path.exists(datafolder+'\\Data_processed\\Data_trials\\'):
    os.makedirs(datafolder+'\\Data_processed\\Data_trials\\')
trialfolder = datafolder+'\\Data_processed\\Data_trials\\' # outputfolder trialbased

# ap all the folders in the target folder
datafolders = glob.glob(experiment_to_process+'*\\')

# Extract the folder IDs
datafolders_id = [x.split('\\')[-2] for x in datafolders]

# print(curfolder)
# print(targetfolder)
print(datafolders_id)

# Identify all xdf files and all the associated triallist info
xdffiles = []
trialdatas = []

for i in datafolders_id:
    file = glob.glob(experiment_to_process+i+'\\*.xdf')
    trialfile = experiment_to_process+i+'\\'+i+'_results'+'.csv'
    trialdatas.append(trialfile)
    xdffiles.extend(file)

# These are the xdf files we need to process
print(xdffiles[0:10])
print(trialdatas[0:10])
# Out:
# ['53_2']
# ['f:\\desync_xdf\\raw\\53_2\\53_2_session.xdf']
# ['f:\\desync_xdf\\raw\\53_2\\53_2_results.csv']

# %% [markdown]
# # Extracting streams from XDF file
#
# Using `pyxdf` package, we can extract the streams from the XDF file.
#
# First, we extract streams for the whole session. Then, we cut these streams into trial-sized chunks, based on the marker stream that indicates the start of each trial. Moreover, we connect the trial with information from the PsychoPy log file, which includes metadata about the trial (i.e., concept, correction number, etc.)
#
# (Note that this code takes some time to execute.)

# %%
#| code-fold: true
#| code-summary: Code with functions
#| eval: false

# Audio write function
def to_audio(fileloc, timeseries, samplerate = 16000, channels = 1):
    obj = wave.open(fileloc,'w')
    obj.setnchannels(channels) # mono
    obj.setsampwidth(2)
    obj.setframerate(float(samplerate))
    for i in timeseries:
        data = struct.pack('<h', int(i[0]))
        obj.writeframesraw( data )
    obj.close()

# Function to retrieve closest value
def find_closest_value_and_retrieve(df, target_number, target_column, retrieve_column):
    # Get the absolute differences between a value in column and the target number
    differences = abs(df[target_column] - target_number)
    
    # Find the index of the minimum difference
    min_difference_index = differences.idxmin()
    
    # Retrieve the corresponding value from the column
    result_value = df.loc[min_difference_index, retrieve_column]

    return result_value

def write_video(vidloc, fourcc, originalfps, frameWidth, frameHeight, capture, frames):
    out = cv2.VideoWriter(vidloc, fourcc, fps = originalfps, frameSize = (int(frameWidth), int(frameHeight)))
    print('Looping over frames')

    # index the frames of the current trial ##FLAG! I have the feeling you are repeating this type of video writing a lot, why not a handy function
    for fra in frames:
        capture.set(cv2.CAP_PROP_POS_FRAMES, fra)
        ret, frame = capture.read()
        if ret:
            out.write(frame)
            
        if not ret:
            print('a frame was dropped: ' + str(fra))
        
    capture.release()
    out.release()

# Alternative if frame query does not work
def write_video2(vidloc, fourcc, originalfps, frameWidth, frameHeight, capture, frame_range):
    out = cv2.VideoWriter(vidloc, fourcc, fps=originalfps, 
                            frameSize=(int(frameWidth), int(frameHeight)))

    frame_count = 0
    while True:
        ret, frame = capture.read()
        if not ret:
            break

        if frame_count in frame_range:
            out.write(frame)

        frame_count += 1

    capture.release()
    out.release()

# %%
#| code-fold: false
#| code-summary: Code to extract streams from XDF files
#| eval: false

errorlist = []

for dat in datafolders_id:

    print('Loading in data from participant: ' + dat)
    trialdata = pd.read_csv(experiment_to_process+dat+'\\'+dat+'_results.csv', sep=",")
    #print(trialdata)
    
    # Get the xdf file
    files = glob.glob(experiment_to_process+dat+'\\*.xdf')
    
    # Look into the files and if there is some with initiated, set Except=True
    if any('reinitiated' in file for file in files):
        Except = True
    else:
        Except = False

    # Ignore files that have reinitiated in the name
    files = [x for x in files if 'reinitiated' not in x]
    files = [x for x in files if 'onlytpose' not in x]

    streams, header = pyxdf.load_xdf(files[0], 
                                     synchronize_clocks=True,
                                     dejitter_timestamps=True,     
                                     handle_clock_resets=False)   

    # We need to handle MarkerStream first
    # Process the MyMarkerStream first
    marker_stream = None
    for stream in streams:
        if stream['info']['name'][0] == 'MyMarkerStream':
            marker_stream = stream
            break

    if marker_stream is None:
        print(f"No MyMarkerStream found for participant {dat}, skipping...")
        continue

    # Save MyMarkerStream as CSV
    print("Processing MyMarkerStream...")
    timevec = marker_stream['time_stamps']
    timeseries = marker_stream['time_series']
    matrix_aux = np.vstack([np.transpose(timevec), np.transpose(timeseries)])
    matrix = np.transpose(matrix_aux)
    df_marker = pd.DataFrame(matrix)
    marker_csv_path = outputfolder + dat + '_MyMarkerStream_nominal_srate0.csv'
    df_marker.to_csv(marker_csv_path, index=False)

    # Load the MyMarkerStream
    markers = pd.read_csv(outputfolder+dat+'_MyMarkerStream_nominal_srate0.csv')
    # Find the row in second column where it says 'Experiment_end'

    # If last row of markers is not Next_word or Experiment_end, check if it's Trial_start
    if markers.iloc[-1][1] != 'Next_word' and markers.iloc[-1][1] != 'Experiment_end':
        if 'Trial_start' in markers.iloc[-1][1]:
            print('Last row is buggy marker, remove...')
            markers = markers.iloc[:-1]

    # We go through each stream and save it as a csv, 
    # If it's Mic stream, also as a .wav file
    for stream in streams:
        #print(streams)

        if stream['info']['name'][0] == 'MyMarkerStream':
            continue  # Skip as it has already been processed
        
        timeseriestype = stream['info']['name'][0]
        samplerate = round(float(stream['info']['nominal_srate'][0]))
        # In the xdf loop over the streams and save it as csv if not yet exists
        channelcount = stream['info']['channel_count'][0]
        print('working on stream: ' + timeseriestype + '  with a channel count of ' + str(channelcount) +'\n and a sampling rate of ' + str(samplerate))
        timevec = stream['time_stamps']
        timeseries = stream['time_series']
        matrix_aux = np.vstack([np.transpose(timevec),np.transpose(timeseries)])
        matrix = np.transpose(matrix_aux)
        df_lab = pd.DataFrame(matrix)
        df_lab.to_csv(outputfolder+dat+'_'+timeseriestype+'_nominal_srate'+str(samplerate)+'.csv',index=False)


        # For audio data also create a wav file
        if timeseriestype == 'Mic':
            if not os.path.exists(outputfolder+'Audio\\'):
                os.makedirs(outputfolder+'Audio\\')
            wavloc = outputfolder+'Audio/'+dat+'_'+timeseriestype+'_nominal_srate'+str(samplerate)+'.wav'
            to_audio(wavloc, timeseries)
            # Load data
            rate, data = wavfile.read(wavloc)
            # Perform noise reduction
            reduced_noise = nr.reduce_noise(y=data, sr=rate, n_std_thresh_stationary=1.5,stationary=True)
            # If folder Audio doesn't exist, create it
            wavloc2 = outputfolder+'Audio/'+dat+'_'+timeseriestype+'_nominal_srate'+str(samplerate)+'_denoised.wav'
            wavfile.write(wavloc2, rate, reduced_noise)

        print('done with processing a complete time series and audio data')
        print('we will now start making trial snipped data') 
        
        # Cut all timeseries to trial level based on the markers
        if timeseriestype != 'MyMarkerStream':
            
            beginlist = []
            endlist = []
            timestamps = []
            timestamps_2 = []
            tpose_starts = []
            tpose_ends = []

            # Iterate over markers and save times of trial starts and ends
            for row in markers.iterrows():
                # Accessing positional elements explicitly with .iloc
                if 'Trial_start' in row[1].iloc[1] or 'Practice trial starts' in row[1].iloc[1]:
                    beginlist.append(row[1].iloc[0])
                if 'Trial_end' in row[1].iloc[1] or 'Practice trial ends' in row[1].iloc[1]:
                    endlist.append(row[1].iloc[0])
                if 'Experiment_start' in row[1].iloc[1]:
                    timestamps.append(row[1].iloc[0])
                if 'New block starts' in row[1].iloc[1]:
                    timestamps_2.append(row[1].iloc[0])
                if 'Tpose starts' in row[1].iloc[1]:
                    tpose_starts.append(row[1].iloc[0])
                if 'Tpose ends' in row[1].iloc[1]:
                    tpose_ends.append(row[1].iloc[0])
                    
            # Converting coefficient for lsl to psychopy time
            exp_start_pp = float(trialdata['exp_start'][0])
            # Get to lsl_to_pp coefficient
            if Except == False:
                if timestamps != []:
                    lsl_to_pp = timestamps[0] - exp_start_pp
                else:
                    # If there is three timestamps in timestamps2, then all is fine and we can use the first one
                    if len(timestamps_2) == 3:
                        block_start_pp = float(trialdata['block_start'][0])
                    # If there is only two timestamps, then we need to assess the second unique value from trialdata
                    elif len(timestamps_2) == 3:
                        # Get the unique values from trialdata
                        unique_values = trialdata['block_start'].unique()
                        # Get the second unique value
                        block_start_pp = unique_values[1]
                    else:
                        unique_values = trialdata['block_start'].unique()
                        # We take the third
                        block_start_pp = unique_values[2]
                        
                    lsl_to_pp = timestamps_2[0] - block_start_pp

            elif Except == True and dat != '36_2':
                if timestamps != []:
                    lsl_to_pp = timestamps[0] - exp_start_pp
                else:
                    if len(timestamps_2) == 3:
                        block_start_pp = float(trialdata['block_start'][0])
                    else:
                        unique_values = trialdata['block_start'].unique()
                        block_start_pp = unique_values[0]

                    lsl_to_pp = timestamps_2[0] - block_start_pp

            elif Except == True and dat == '36_2':
                if timestamps != []:
                    lsl_to_pp = timestamps[0] - exp_start_pp
                else:
                    if len(timestamps_2) == 3:
                        block_start_pp = float(trialdata['block_start'][0])
                    else:
                        unique_values = trialdata['block_start'].unique()
                        block_start_pp = unique_values[1]

                    lsl_to_pp = timestamps_2[0] - block_start_pp

        
            # Now we can proceed to cutting   
            for i in range(len(beginlist)):
                # Prepare the range of the trial
                begin = beginlist[i]
                print(begin)
                end = endlist[i]
                indices = (df_lab.loc[:,0] >= begin) & (df_lab.loc[:,0] <= end)
                print(indices)
                beginst = min(df_lab.loc[:,0]) # start time of the timeseries
                endst = max(df_lab.loc[:,0])  # end time of the timeseries
                subset = df_lab.loc[indices, :]
                print(subset)
                # Convert the beginst to psychopy time
                beginst_pp = begin - lsl_to_pp
                # Now find in trialdata the closest time to the beginst_pp to gather info
                # Whether it is practice or trial
                practice = find_closest_value_and_retrieve(trialdata, beginst_pp, 'trial_start', 'practice')
                if practice == 'practice':
                    trialtype = 'pr'
                else:
                    trialtype = 'trial'
                
                # Which participant it is
                cycle = find_closest_value_and_retrieve(trialdata, beginst_pp, 'trial_start', 'cycle')
                if cycle == 0:
                    participant = 'p0'
                else:
                    participant = 'p1'

                # What concept it is
                word = find_closest_value_and_retrieve(trialdata, beginst_pp, 'trial_start', 'word')
                # Modality
                modality = find_closest_value_and_retrieve(trialdata, beginst_pp, 'trial_start', 'modality')
                # Correction, if applicable
                correction_info = find_closest_value_and_retrieve(trialdata, beginst_pp, 'trial_start', 'correction')
                if correction_info == 0:
                    correction = '_c0'
                elif correction_info == 1:
                    correction = '_c1'
                elif correction_info == 2:
                    correction = '_c2'
                else:
                    correction = ''
                
                # Continue saving
                if(len(subset.axes[0])<2):
                    errorlist.append(dat + " for "+ timeseriestype + " for trial " + str(i) + 'NO DATA WITHIN RANGE...')
                if(len(subset.axes[0])>2):
                     # Save subset to csv
                      subset.to_csv(trialfolder+dat+'_'+trialtype+'_'+ str(i) +'_'+timeseriestype+'_nominal_srate'+str(samplerate)+'_'+participant+'_'+word+'_'+modality+correction+'.csv', index=False)
                      if timeseriestype == 'Mic':
                            # If folder Audio doesn't exist, create it
                            if not os.path.exists(trialfolder+'Audio\\'):
                                os.makedirs(trialfolder+'Audio\\')
                            wavloc = trialfolder+'Audio/'+dat+'_'+trialtype+'_'+ str(i) +'_'+timeseriestype+'_nominal_srate'+str(samplerate)+'_'+participant+'_'+word+'_'+modality+correction+'.wav'
                            to_audio(wavloc, timeseries[indices])
                            # Also apply denoising
                            reduced_noiseclip = reduced_noise[indices]
                            wavloc2 = trialfolder+'Audio/'+dat+'_'+trialtype+'_'+ str(i) +'_'+timeseriestype+'_nominal_srate'+str(samplerate)+'_'+participant+'_'+word+'_'+modality+correction+'_denoised.wav'
                            wavfile.write(wavloc2, rate, reduced_noiseclip)
            
            # Get information about the tpose for camera
            if timeseriestype == 'MyWebcamFrameStream':
                for i in range(len(tpose_starts)):
                    begin = tpose_starts[i]
                    end = tpose_ends[i]
                    indices = (df_lab.loc[:,0] > begin) & (df_lab.loc[:,0] < end)
                    beginst = min(df_lab.loc[:,0])
                    endst = max(df_lab.loc[:,0])
                    subset = df_lab.loc[indices, :]
                    # Save subset to csv
                    subset.to_csv(trialfolder+dat+'_'+'tpose_'+ str(i) +'_'+timeseriestype+'_nominal_srate'+str(samplerate)+'.csv', index=False)
        
        # After every stream we'll save the error log
        errors = pd.DataFrame(errorlist, columns=['file_error'])
        # Get todays date
        today = pd.Timestamp("today").strftime("%Y_%m")
        file_path = errorlogs+'error_log_cuttingtrails' + today + '.csv'
        errors.to_csv(file_path, index=False) 
        
print('Were done: proceed to snipping videos to triallevel')
# Out:
# Loading in data from participant: 53_2
# Processing MyMarkerStream...
# working on stream: MyWebcamFrameStream  with a channel count of 1
#  and a sampling rate of 500
# C:\Users\kadava\AppData\Local\Temp\ipykernel_15560\1668903454.py:58: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if markers.iloc[-1][1] != 'Next_word' and markers.iloc[-1][1] != 'Experiment_end':
# C:\Users\kadava\AppData\Local\Temp\ipykernel_15560\1668903454.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if 'Trial_start' in markers.iloc[-1][1]:
# done with processing a complete time series and audio data
# we will now start making trial snipped data
# 8899.48028193189
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1039480    False
# 1039481    False
# 1039482    False
# 1039483    False
# 1039484    False
# Name: 0, Length: 1039485, dtype: bool
#                  0       1
# 16470  8899.480713  4657.0
# 16471  8899.482773  4657.0
# 16472  8899.484833  4657.0
# 16473  8899.486894  4657.0
# 16474  8899.488954  4657.0
# ...            ...     ...
# 18965  8904.620496  4944.0
# 18966  8904.622556  4944.0
# 18967  8904.624616  4945.0
# 18968  8904.626676  4945.0
# 18969  8904.628736  4945.0
#
# [2500 rows x 2 columns]
# 8914.456248546887
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1039480    False
# 1039481    False
# 1039482    False
# 1039483    False
# 1039484    False
# Name: 0, Length: 1039485, dtype: bool
#                  0       1
# 23740  8914.457154  5393.0
# 23741  8914.459214  5393.0
# 23742  8914.461275  5393.0
# 23743  8914.463335  5393.0
# 23744  8914.465395  5393.0
# ...            ...     ...
# 27051  8921.277924  5704.0
# 27052  8921.279984  5704.0
# 27053  8921.282044  5704.0
# 27054  8921.284104  5704.0
# 27055  8921.286164  5704.0
#
# [3316 rows x 2 columns]
# 8937.304826026711
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1039480    False
# 1039481    False
# 1039482    False
# 1039483    False
# 1039484    False
# Name: 0, Length: 1039485, dtype: bool
#                  0       1
# 34831  8937.304982  6436.0
# 34832  8937.307042  6436.0
# 34833  8937.309102  6436.0
# 34834  8937.311162  6436.0
# 34835  8937.313222  6436.0
# ...            ...     ...
# 40047  8948.050115  6923.0
# 40048  8948.052175  6923.0
# 40049  8948.054235  6924.0
# 40050  8948.056295  6924.0
# 40051  8948.058355  6924.0
#
# [5221 rows x 2 columns]
# 8963.68703338993
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1039480    False
# 1039481    False
# 1039482    False
# 1039483    False
# 1039484    False
# Name: 0, Length: 1039485, dtype: bool
#
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 34537765    False
# 34537766    False
# 34537767    False
# 34537768    False
# 34537769    False
# Name: 0, Length: 34537770, dtype: bool
#                      0      1
# 33404494  10957.680746  -67.0
# 33404495  10957.680808  -65.0
# 33404496  10957.680871  -95.0
# 33404497  10957.680933 -105.0
# 33404498  10957.680996 -104.0
# ...                ...    ...
# 33471081  10961.842224  191.0
# 33471082  10961.842286  194.0
# 33471083  10961.842349  190.0
# 33471084  10961.842411  164.0
# 33471085  10961.842474  187.0
#
# [66592 rows x 2 columns]
# 10967.577036135111
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 34537765    False
# 34537766    False
# 34537767    False
# 34537768    False
# 34537769    False
# Name: 0, Length: 34537770, dtype: bool
#                      0      1
# 33562843  10967.577061  -61.0
# 33562844  10967.577123  -65.0
# 33562845  10967.577186  -56.0
# 33562846  10967.577248  -83.0
# 33562847  10967.577311 -132.0
# ...                ...    ...
# 33620754  10971.196316   69.0
# 33620755  10971.196379   45.0
# 33620756  10971.196441   29.0
# 33620757  10971.196504   78.0
# 33620758  10971.196566   81.0
#
# [57916 rows x 2 columns]
# 10984.072139142016
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 34537765    False
# 34537766    False
# 34537767    False
# 34537768    False
# 34537769    False
# Name: 0, Length: 34537770, dtype: bool
#                      0      1
# 33826778  10984.072168  236.0
# 33826779  10984.072231  243.0
# 33826780  10984.072293  238.0
# 33826781  10984.072356  192.0
# 33826782  10984.072418  127.0
# ...                ...    ...
# 33898317  10988.543131   57.0
# 33898318  10988.543194   25.0
# 33898319  10988.543256  -21.0
# 33898320  10988.543319  -20.0
# 33898321  10988.543381  -48.0
#
# [71544 rows x 2 columns]
# 10997.912739825202
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 34537765    False
# 34537766    False
# 34537767    False
# 34537768    False
# 34537769    False
# Name: 0, Length: 34537770, dtype: bool
#                      0      1
# 34048239  10997.912785  100.0
# 34048240  10997.912847   66.0
# 34048241  10997.912910   82.0
# 34048242  10997.912972   90.0
# 34048243  10997.913035   89.0
# ...                ...    ...
# 34109407  11001.735593 -131.0
# 34109408  11001.735655 -103.0
# 34109409  11001.735718  -73.0
# 34109410  11001.735780  -92.0
# 34109411  11001.735843  -31.0
#
# [61173 rows x 2 columns]
# Were done: proceed to snipping videos to triallevel

# %% [markdown]
# Now we have raw data for each trial in csv and wav, but we still need to write videos for each trial. We will use the trial-cut files to access the range of frames in the original raw video file and cut it out from it

# %%
#| code-fold: true
#| code-summary: Code to prepare folders

# This is a folder with timeseries
tsfolder = datafolder+'\\Data_processed\\Data_trials\\'
# This is where the raw long video is
videofolder = curfolder + '\\raw\\'

# %%
#| code-fold: false
#| code-summary: Code to cut video intro trial-sized snippets
#| eval: false

# Loop through the csv's in tsfolder that has string 'MyWebcamStream' in name
for file in os.listdir(tsfolder):

    if '53_2' not in file:
        continue

    if 'MyWebcamFrameStream' in file:
        if '_rein_' in file:
            print('Now processing file '+ file)
            # If it is a tpose file, we skip it for now
            if 'tpose' in file:
                continue

            # The name looks like this 0_1_trial_0_MyWebcamFrameStream_nominal_srate500_p0_bitter_geluiden.csv
            dyadIndex = file.split('_')[0]   # this is dyad number
            partIndex = file.split('_')[1]   # this is part of the session
            sessionIndex = dyadIndex + '_' + partIndex # this is the session index
            trialIndex = file.split('_')[4] # this is trial number
            participant = file.split('_')[8] # this is participant 0/1
            word = file.split('_')[9] # this is the concept
            modality = file.split('_')[10].split('.')[0] # this is the modality

            # Assess the correction
            if 'c0' in file:
                correction = '_c0'
            elif 'c1' in file:
                correction = '_c1'
            elif 'c2' in file:
                correction = '_c2'
            else:
                correction = ''

            # Assess the trial type
            if 'pr' in file:
                trialtype = 'pr'
            else:
                trialtype = 'trial'

            trialdata = pd.read_csv(tsfolder+file)
            #print(trialdata)

            # This is the location where the video will be saved
            vidloc = trialfolder+sessionIndex+'_rein_'+trialtype+'_'+ str(trialIndex) +'_'+participant+'_'+word+'_'+modality+correction+'_video_raw'+'.avi'

            # Check if it exists, if yes, skip
            # if os.path.exists(vidloc):
            #     print('Video already exists, skipping...')
            #     continue
            
            videolong = videofolder+sessionIndex+'\\'+sessionIndex+'_reinitiated-video.avi' # this is the long video 
        else:
            print('Now processing file '+ file)
            # If it is a tpose file, we skip it for now
            if 'tpose' in file:
                continue

            # The name looks like this 0_1_trial_0_MyWebcamFrameStream_nominal_srate500_p0_bitter_geluiden.csv
            dyadIndex = file.split('_')[0]   # this is dyad number
            partIndex = file.split('_')[1]   # this is part of the session
            sessionIndex = dyadIndex + '_' + partIndex # this is the session index
            trialIndex = file.split('_')[3] # this is trial number
            participant = file.split('_')[7] # this is participant 0/1
            word = file.split('_')[8] # this is the concept
            modality = file.split('_')[9].split('.')[0] # this is the modality

            # Assess the correction
            if 'c0' in file:
                correction = '_c0'
            elif 'c1' in file:
                correction = '_c1'
            elif 'c2' in file:
                correction = '_c2'
            else:
                correction = ''

            # Assess the trial type
            if 'pr' in file:
                trialtype = 'pr'
            else:
                trialtype = 'trial'

            trialdata = pd.read_csv(tsfolder+file)
            #print(trialdata)

            # This is the location where the video will be saved
            vidloc = trialfolder+sessionIndex+'_'+trialtype+'_'+ str(trialIndex) +'_'+participant+'_'+word+'_'+modality+correction+'_video_raw'+'.avi'

            # # Check if it exists, if yes, skip
            # if os.path.exists(vidloc):
            #     print('Video already exists, skipping...')
            #     continue
            
            videolong = videofolder+sessionIndex+'\\'+sessionIndex+'-video.avi' # this is the long video 
        #print(videolong)
        begin_time = trialdata['0'].min() # begin time of the trial
        end_time = trialdata['0'].max() # end time of the trial
        # Get the begin and end frame
        begin_frame = trialdata['1'].min().astype(int)
        end_frame = trialdata['1'].max().astype(int)
        totframes = end_frame-begin_frame # total number of frames in the trial
        frames = range(begin_frame, end_frame) # get all the frames in trial
        #print(frames)
        # Load in the long video
        print('Loading the original video')
        capture = cv2.VideoCapture(videolong) 

        # what is the original fps of the video
        originalfps = round((totframes/(end_time-begin_time)),3)
        #print('original fps: '+str(originalfps))
        
        # Metadata
        fourcc = cv2.VideoWriter_fourcc(*'XVID')
        frameWidth = capture.get(cv2.CAP_PROP_FRAME_WIDTH)
        frameHeight = capture.get(cv2.CAP_PROP_FRAME_HEIGHT)

        # Start writing video
        print('Starting to write the video')
        write_video(vidloc, fourcc, originalfps, frameWidth, frameHeight, capture, frames)
        print('Video is done')

print('All done!')
# Out:
# Now processing file 53_2_pr_0_MyWebcamFrameStream_nominal_srate500_p0_vliegtuig_gebaren_c0.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_pr_1_MyWebcamFrameStream_nominal_srate500_p0_vliegtuig_gebaren_c1.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_pr
combinatie_c0.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_pr_94_MyWebcamFrameStream_nominal_srate500_p1_telefoon_combinatie_c0.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_pr_95_MyWebcamFrameStream_nominal_srate500_p1_telefoon_combinatie_c1.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_96_MyWebcamFrameStream_nominal_srate500_p1_kind_combinatie_c0.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_97_MyWebcamFrameStream_nominal_srate500_p1_snel_combinatie_c0.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_98_MyWebcamFrameStream_nominal_srate500_p1_snel_combinatie_c1.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_99_MyWebcamFrameStream_nominal_srate500_p1_bang_combinatie_c0.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_100_MyWebcamFrameStream_nominal_srate500_p1_zuur_combinatie_c0.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_101_MyWebcamFrameStream_nominal_srate500_p1_zuur_combinatie_c1.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_102_MyWebcamFrameStream_nominal_srate500_p1_zuur_combinatie_c2.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_103_MyWebcamFrameStream_nominal_srate500_p1_piepen_combinatie_c0.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_104_MyWebcamFrameStream_nominal_srate500_p1_piepen_combinatie_c1.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_105_MyWebcamFrameStream_nominal_srate500_p1_piepen_combinatie_c2.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_106_MyWebcamFrameStream_nominal_srate500_p1_grommen_combinatie_c0.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_107_MyWebcamFrameStream_nominal_srate500_p1_grommen_combinatie_c1.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_108_MyWebcamFrameStream_nominal_srate500_p1_grommen_combinatie_c2.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# Now processing file 53_2_trial_109_MyWebcamFrameStream_nominal_srate500_p1_rennen_combinatie_c0.csv
# Loading the original video
# Starting to write the video
# Looping over frames
# Video is done
# All done!

# %% [markdown]
# # Concatenating audio and video
#
# We do not necessarilly need to have video and audio combined, but we do want to check whether they are synchronized (they should be, but it's always good to do a sanity check).
#
# We will combine the audio and video for each trial using `ffmpeg` package, and save it as a new video file.

# %%
#| code-fold: false
#| code-summary: Code to prepare environment

wavloc = trialfolder+'Audio\\'
wavfiles = glob.glob(wavloc+'*denoised.wav')
audiovideo = datafolder+'Data_processed\\AudioVideo\\'

# if the folder doesn't exist, create it
if not os.path.exists(audiovideo):
    os.makedirs(audiovideo)
    
videofolder = datafolder+'Data_processed\\Data_trials\\'

# Inititate error log
errorlog2 = []

# loop over Audio files
for file in wavfiles:

    print('Now processing file '+file)

    filename = file.split('\\')[-1].split('.')[0]

    dyadIndex = filename.split('_')[0]   # this is dyad number
    partIndex = filename.split('_')[1]   # this is part of the session
    sessionIndex = dyadIndex + '_' + partIndex # this is the session index
    print(sessionIndex)

    if sessionIndex != '53_2':
        continue

    if '_rein_' in file:
        trialIndex = filename.split('_')[4] # this is trial number
        participant = filename.split('_')[8] # this is participant 0/1
        word = filename.split('_')[9] # this is the word
        modality = filename.split('_')[10] # this is the modality

    else: 
        trialIndex = filename.split('_')[3] # this is trial number
        participant = filename.split('_')[7] # this is participant 0/1
        word = filename.split('_')[8] # this is the word
        modality = filename.split('_')[9] # this is the modality

    # handle correction
    if 'c0' in file:
        correction = '_c0'
    elif 'c1' in file:
        correction = '_c1'
    elif 'c2' in file:
        correction = '_c2'
    else:
        correction = ''
    # trial type
    if '_pr_' in file:
        trialtype = 'pr'
    else:
        trialtype = 'trial'

    # if it's corrected file or not
    if 'corrected' in file:
        add = '_corrected'
    else:
        add = ''

    if '_rein_' in file:
        output_path = os.path.abspath(os.path.join(audiovideo, f"{sessionIndex}_rein_{trialtype}_{trialIndex}_{participant}_{word}_{modality}{correction}_final.avi"))

    else:
        output_path = os.path.abspath(os.path.join(audiovideo, f"{sessionIndex}_{trialtype}_{trialIndex}_{participant}_{word}_{modality}{correction}_final.avi"))

    # if os.path.exists(output_path):
    #     print('Video already exists, skipping...')
    #     continue

    #load in the audio
    print('Loading the audio')
    audio_path = os.path.join(wavloc, file)
    if not os.path.exists(audio_path):
        print(f"Audio file not found: {audio_path}")

    # input the video with ffmpg
    input_audio = ffmpeg.input(audio_path)
    print(input_audio)
    #load in the video with matchich trialIndex and SessionIndex
    print('Loading the video')
    if '_rein_' in file:
        video_path = os.path.join(videofolder + f"{sessionIndex}_rein_{trialtype}_{trialIndex}_{participant}_{word}_{modality}{add}{correction}_video_raw.avi")
    else:
        video_path = os.path.join(videofolder + f"{sessionIndex}_{trialtype}_{trialIndex}_{participant}_{word}_{modality}{add}{correction}_video_raw.avi")

    if not os.path.exists(video_path):
        print(f"Video file not found: {video_path}")
    input_video = ffmpeg.input(video_path)
    print(input_video)
    
    #combine the audio and video
    print('Combining audio and video')

    try:
        ffmpeg.concat(input_video, input_audio, v=1, a=1).output(
            output_path,
            vcodec='libx264',
            acodec='aac',
            video_bitrate='2M',         
            
            ).run(overwrite_output=True)
    except:
        print('Error in combining audio and video')
        errorlog2.append(file)
        continue
        
# Write the error log
errorlog = pd.DataFrame(errorlog2)
errorlog.to_csv(audiovideo + 'errorlog2_audio_video.csv', index = False)
print('All done!')
# Out:
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_0_Mic_nominal_srate16000_p0_vliegtuig_gebaren_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_0_Mic_nominal_srate16000_p0_vliegtuig_gebaren_c0_denoised.wav')[None] <b811b8b9acc2>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_0_p0_vliegtuig_gebaren_c0_video_raw.avi')[None] <99745973a6a1>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_1_Mic_nominal_srate16000_p0_vliegtuig_gebaren_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_1_Mic_nominal_srate16000_p0_vliegtuig_gebaren_c1_denoised.wav')[None] <79a3e28a6795>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_1_p0_vliegtuig_gebaren_c1_video_raw.avi')[None] <8ee576474b0a>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_2_Mic_nominal_srate16000_p0_vliegtuig_gebaren_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_2_Mic_nominal_srate16000_p0_vliegtuig_gebaren_c2_denoised.wav')[None] <d9ce92d507cc>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_2_p0_vliegtuig_gebaren_c2_video_raw.avi')[None] <135cff93ccf0>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_3_Mic_nominal_srate16000_p0_glimlach_gebaren_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_3_Mic_nominal_srate16000_p0_glimlach_gebaren_c0_denoised.wav')[None] <9d21779febfd>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_3_p0_glimlach_gebaren_c0_video_raw.avi')[None] <1efcf7383d93>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_4_Mic_nominal_srate16000_p0_glimlach_gebaren_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_4_Mic_nominal_srate16000_p0_glimlach_gebaren_c1_denoised.wav')[None] <1f66a304e232>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_4_p0_glimlach_gebaren_c1_video_raw.avi')[None] <110eb5f07384>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_5_Mic_nominal_srate16000_p0_glimlach_gebaren_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_5_Mic_nominal_srate16000_p0_glimlach_gebaren_c2_denoised.wav')[None] <d7759d8ca44c>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_5_p0_glimlach_gebaren_c2_video_raw.avi')[None] <63b79ac5efb2>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_6_Mic_nominal_srate16000_p0_walgen_gebaren_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_6_Mic_nominal_srate16000_p0_walgen_gebaren_c0_denoised.wav')[None] <a77fa05513f8>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_6_p0_walgen_gebaren_c0_video_raw.avi')[None] <10cffcd0ca80>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial
c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_33_Mic_nominal_srate16000_p0_bal_geluiden_c1_denoised.wav')[None] <29793984c6fa>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_33_p0_bal_geluiden_c1_video_raw.avi')[None] <1a23e842ca9f>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_34_Mic_nominal_srate16000_p0_bal_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_34_Mic_nominal_srate16000_p0_bal_geluiden_c2_denoised.wav')[None] <1f9f2e15ec22>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_34_p0_bal_geluiden_c2_video_raw.avi')[None] <b31de12c02e0>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_35_Mic_nominal_srate16000_p0_geheim_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_35_Mic_nominal_srate16000_p0_geheim_geluiden_c0_denoised.wav')[None] <175718419c8c>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_35_p0_geheim_geluiden_c0_video_raw.avi')[None] <7a7ef34a1244>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_36_Mic_nominal_srate16000_p0_geheim_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_36_Mic_nominal_srate16000_p0_geheim_geluiden_c1_denoised.wav')[None] <1167fb12bcc3>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_36_p0_geheim_geluiden_c1_video_raw.avi')[None] <ffd5c60cb561>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_37_Mic_nominal_srate16000_p0_geheim_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_37_Mic_nominal_srate16000_p0_geheim_geluiden_c2_denoised.wav')[None] <c279031aae4b>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_37_p0_geheim_geluiden_c2_video_raw.avi')[None] <ed9bbee2aa49>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_38_Mic_nominal_srate16000_p0_vogel_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_38_Mic_nominal_srate16000_p0_vogel_geluiden_c0_denoised.wav')[None] <2aaf16064717>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_38_p0_vogel_geluiden_c0_video_raw.avi')[None] <18cd0c309cbc>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_39_Mic_nominal_srate16000_p0_vogel_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_39_Mic_nominal_srate16000_p0_vogel_geluiden_c1_denoised.wav')[None] <1d85faa13481>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_39_p0_vogel_geluiden_c1_video_raw.avi')[None] <9d69b3ef069b>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_40_Mic_nominal_srate16000_p0_vogel_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_40_Mic_nominal_srate16000_p0_vogel_geluiden_c2_denoised.wav')[None] <bc45a17b9469>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_40_p0_vogel_geluiden_c2_video_raw.avi')[None] <107fea6c5e9b>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_41_Mic_nominal_srate16000_p0_bitter_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_41_Mic_nominal_srate16000_p0_bitter_geluiden_c0_denoised.wav')[None] <1ba921be9b64>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_41_p0_bitter_geluiden_c0_video_raw.avi')[None] <1f3ad0534169>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_42_Mic_nominal_srate16000_p0_bitter_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_42_Mic_nominal_srate16000_p0_bitter_geluiden_c1_denoised.wav')[None] <12876a383c81>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_42_p0_bitter_geluiden_c1_video_raw.avi')[None] <a3d4e8fcb0a5>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_43_Mic_nominal_srate16000_p0_bitter_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_43_Mic_nominal_srate16000_p0_bitter_geluiden_c2_denoised.wav')[None] <1066aeb36544>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_43_p0_bitter_geluiden_c2_video_raw.avi')[None] <8782025eff23>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_44_Mic_nominal_srate16000_p0_hond_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_44_Mic_nominal_srate16000_p0_hond_geluiden_c0_denoised.wav')[None] <1db235604de8>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_44_p0_hond_geluiden_c0_video_raw.avi')[None] <56a7886453ca>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_45_Mic_nominal_srate16000_p0_geur_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_45_Mic_nominal_srate16000_p0_geur_geluiden_c0_denoised.wav')[None] <b84c210ced22>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_45_p0_geur_geluiden_c0_video_raw.avi')[None] <3202368a5ba6>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_46_Mic_nominal_srate16000_p0_geur_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_46_Mic_nominal_srate16000_p0_geur_geluiden_c1_denoised.wav')[None] <1e03faaf5d3d>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_46_p0_geur_geluiden_c1_video_raw.avi')[None] <164964d3c387>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_47_Mic_nominal_srate16000_p0_geur_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_47_Mic_nominal_srate16000_p0_geur_geluiden_c2_denoised.wav')[None] <bd5aea9479cd>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_47_p0_geur_geluiden_c2_video_raw.avi')[None] <132b80180d45>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_48_Mic_nominal_srate16000_p0_zoet_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_48_Mic_nominal_srate16000_p0_zoet_geluiden_c0_denoised.wav')[None] <c0d97101fe83>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_48_p0_zoet_geluiden_c0_video_raw.avi')[None] <1e1674e9dc48>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_49_Mic_nominal_srate16000_p0_zoet_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_49_Mic_nominal_srate16000_p0_zoet_geluiden_c1_denoised.wav')[None] <d8fa889d2513>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_49_p0_zoet_geluiden_c1_video_raw.avi')[None] <1ef90521b06e>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_50_Mic_nominal_srate16000_p0_zoet_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_50_Mic_nominal_srate16000_p0_zoet_geluiden_c2_denoised.wav')[None] <189eb2df1936>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_50_p0_zoet_geluiden_c2_video_raw.avi')[None] <922f35ba81d4>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_51_Mic_nominal_srate16000_p0_ademen_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_51_Mic_nominal_srate16000_p0_ademen_geluiden_c0_denoised.wav')[None] <f9e7fa3fc24e>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_51_p0_ademen_geluiden_c0_video_raw.avi')[None] <1f0b47151337>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_52_Mic_nominal_srate16000_p0_lopen_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_52_Mic_nominal_srate16000_p0_lopen_geluiden_c0_denoised.wav')[None] <3595ea097009>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_52_p0_lopen_geluiden_c0_video_raw.avi')[None] <18be470263b9>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_53_Mic_nominal_srate16000_p0_lopen_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_53_Mic_nominal_srate16000_p0_lopen_geluiden_c1_denoised.wav')[None] <f82cb6f30eaa>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_53_p0_lopen_geluiden_c1_video_raw.avi')[None] <1114e08e2787>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_54_Mic_nominal_srate16000_p0_lopen_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_54_Mic_nominal_srate16000_p0_lopen_geluiden_c2_denoised.wav')[None] <5e5988e65222>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_54_p0_lopen_geluiden_c2_video_raw.avi')[None] <148764b2126f>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_55_Mic_nominal_srate16000_p1_fiets_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_55_Mic_nominal_srate16000_p1_fiets_geluiden_c0_denoised.wav')[None] <3f26acebbfc9>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_55_p1_fiets_geluiden_c0_video_raw.avi')[None] <15eaf4425cab>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_56_Mic_nominal_srate16000_p1_fiets_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_56_Mic_nominal_srate16000_p1_fiets_geluiden_c1_denoised.wav')[None] <12fd9ef3473d>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_56_p1_fiets_geluiden_c1_video_raw.avi')[None] <19cccd6700c8>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_57_Mic_nominal_srate16000_p1_fiets_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_57_Mic_nominal_srate16000_p1_fiets_geluiden_c2_denoised.wav')[None] <1128b38aa662>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_57_p1_fiets_geluiden_c2_video_raw.avi')[None] <dc5e87c3b80a>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_58_Mic_nominal_srate16000_p1_klok_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_58_Mic_nominal_srate16000_p1_klok_geluiden_c0_denoised.wav')[None] <68bdf8f86681>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_58_p1_klok_geluiden_c0_video_raw.avi')[None] <e64315147c8c>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_59_Mic_nominal_srate16000_p1_klok_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_59_Mic_nominal_srate16000_p1_klok_geluiden_c1_denoised.wav')[None] <1186c56425f8>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_59_p1_klok_geluiden_c1_video_raw.avi')[None] <1d15b1be6415>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_pr_60_Mic_nominal_srate16000_p1_klok_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_pr_60_Mic_nominal_srate16000_p1_klok_geluiden_c2_denoised.wav')[None] <191303ea5cb8>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_pr_60_p1_klok_geluiden_c2_video_raw.avi')[None] <16ae4a90f108>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_61_Mic_nominal_srate16000_p1_koud_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_61_Mic_nominal_srate16000_p1_koud_geluiden_c0_denoised.wav')[None] <46dc60f91832>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_61_p1_koud_geluiden_c0_video_raw.avi')[None] <2dff52e0ee01>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_62_Mic_nominal_srate16000_p1_stil_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_62_Mic_nominal_srate16000_p1_stil_geluiden_c0_denoised.wav')[None] <106e6812861d>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_62_p1_stil_geluiden_c0_video_raw.avi')[None] <7c264a55569e>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_63_Mic_nominal_srate16000_p1_stil_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_63_Mic_nominal_srate16000_p1_stil_geluiden_c1_denoised.wav')[None] <1d4cd6ec1463>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_63_p1_stil_geluiden_c1_video_raw.avi')[None] <164d432581e5>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_64_Mic_nominal_srate16000_p1_langzaam_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_64_Mic_nominal_srate16000_p1_langzaam_geluiden_c0_denoised.wav')[None] <16c444d2dbdc>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_64_p1_langzaam_geluiden_c0_video_raw.avi')[None] <19802e3e083e>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_65_Mic_nominal_srate16000_p1_langzaam_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_65_Mic_nominal_srate16000_p1_langzaam_geluiden_c1_denoised.wav')[None] <b78e659ef6ec>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_65_p1_langzaam_geluiden_c1_video_raw.avi')[None] <1723ecb72f91>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_66_Mic_nominal_srate16000_p1_langzaam_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_66_Mic_nominal_srate16000_p1_langzaam_geluiden_c2_denoised.wav')[None] <cdb88cdb673a>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_66_p1_langzaam_geluiden_c2_video_raw.avi')[None] <1e80377aa76a>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_67_Mic_nominal_srate16000_p1_staart_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_67_Mic_nominal_srate16000_p1_staart_geluiden_c0_denoised.wav')[None] <137bc4e1dafd>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_67_p1_staart_geluiden_c0_video_raw.avi')[None] <47643c6a08fd>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_68_Mic_nominal_srate16000_p1_staart_geluiden_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_68_Mic_nominal_srate16000_p1_staart_geluiden_c1_denoised.wav')[None] <18e741587379>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_68_p1_staart_geluiden_c1_video_raw.avi')[None] <16fbfef76696>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_69_Mic_nominal_srate16000_p1_staart_geluiden_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_69_Mic_nominal_srate16000_p1_staart_geluiden_c2_denoised.wav')[None] <2af061e509de>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_69_p1_staart_geluiden_c2_video_raw.avi')[None] <678aa84d5ea7>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_70_Mic_nominal_srate16000_p1_drinken_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_70_Mic_nominal_srate16000_p1_drinken_geluiden_c0_denoised.wav')[None] <602b97dec9b2>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_70_p1_drinken_geluiden_c0_video_raw.avi')[None] <1327e95229ca>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_71_Mic_nominal_srate16000_p1_springen_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_71_Mic_nominal_srate16000_p1_springen_geluiden_c0_denoised.wav')[None] <de18110201dc>
# Loading the video
# Video file not found: f:\desync_xdf\data\Data_processed\Data_trials\53_2_trial_71_p1_springen_geluiden_c0_video_raw.avi
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_71_p1_springen_geluiden_c0_video_raw.avi')[None] <1f1d049d5020>
# Combining audio and video
# Error in combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_72_Mic_nominal_srate16000_p1_water_geluiden_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial

# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_98_p1_snel_combinatie_c1_video_raw.avi')[None] <dc7e35bfcbdd>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_99_Mic_nominal_srate16000_p1_bang_combinatie_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_99_Mic_nominal_srate16000_p1_bang_combinatie_c0_denoised.wav')[None] <1bc768974e9c>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_99_p1_bang_combinatie_c0_video_raw.avi')[None] <f92d7f95b4f2>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_100_Mic_nominal_srate16000_p1_zuur_combinatie_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_100_Mic_nominal_srate16000_p1_zuur_combinatie_c0_denoised.wav')[None] <1c11a2c78746>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_100_p1_zuur_combinatie_c0_video_raw.avi')[None] <8c3586e8ec38>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_101_Mic_nominal_srate16000_p1_zuur_combinatie_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_101_Mic_nominal_srate16000_p1_zuur_combinatie_c1_denoised.wav')[None] <1a145c507a55>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_101_p1_zuur_combinatie_c1_video_raw.avi')[None] <8753ea826e73>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_102_Mic_nominal_srate16000_p1_zuur_combinatie_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_102_Mic_nominal_srate16000_p1_zuur_combinatie_c2_denoised.wav')[None] <3634c917181d>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_102_p1_zuur_combinatie_c2_video_raw.avi')[None] <16c78f698d09>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_103_Mic_nominal_srate16000_p1_piepen_combinatie_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_103_Mic_nominal_srate16000_p1_piepen_combinatie_c0_denoised.wav')[None] <17d41b5b1601>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_103_p1_piepen_combinatie_c0_video_raw.avi')[None] <5c909e614382>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_104_Mic_nominal_srate16000_p1_piepen_combinatie_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_104_Mic_nominal_srate16000_p1_piepen_combinatie_c1_denoised.wav')[None] <1e44d1a479c0>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_104_p1_piepen_combinatie_c1_video_raw.avi')[None] <571460b3a94e>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_105_Mic_nominal_srate16000_p1_piepen_combinatie_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_105_Mic_nominal_srate16000_p1_piepen_combinatie_c2_denoised.wav')[None] <f3a575c41bf4>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_105_p1_piepen_combinatie_c2_video_raw.avi')[None] <482f20803696>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_106_Mic_nominal_srate16000_p1_grommen_combinatie_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_106_Mic_nominal_srate16000_p1_grommen_combinatie_c0_denoised.wav')[None] <28a7b1d05e85>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_106_p1_grommen_combinatie_c0_video_raw.avi')[None] <b773aec842c0>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_107_Mic_nominal_srate16000_p1_grommen_combinatie_c1_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_107_Mic_nominal_srate16000_p1_grommen_combinatie_c1_denoised.wav')[None] <795fc426b498>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_107_p1_grommen_combinatie_c1_video_raw.avi')[None] <19e727c5b96b>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_108_Mic_nominal_srate16000_p1_grommen_combinatie_c2_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_108_Mic_nominal_srate16000_p1_grommen_combinatie_c2_denoised.wav')[None] <143f141d02cb>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_108_p1_grommen_combinatie_c2_video_raw.avi')[None] <1e305120e0b2>
# Combining audio and video
# Now processing file f:\desync_xdf\data\\Data_processed\Data_trials\Audio\53_2_trial_109_Mic_nominal_srate16000_p1_rennen_combinatie_c0_denoised.wav
# 53_2
# Loading the audio
# input(filename='f:\\desync_xdf\\data\\\\Data_processed\\Data_trials\\Audio\\53_2_trial_109_Mic_nominal_srate16000_p1_rennen_combinatie_c0_denoised.wav')[None] <1da8299a8cc3>
# Loading the video
# input(filename='f:\\desync_xdf\\data\\Data_processed\\Data_trials\\53_2_trial_109_p1_rennen_combinatie_c0_video_raw.avi')[None] <1655d4db830e>
# Combining audio and video
# All done!
